# %%
import pandas as pd
import numpy as np
import seaborn as sns
import  matplotlib.pyplot as plt
# %matplotlib inline

# %%
concentrations= pd.read_csv(r"C:\Users\U_M10Q3\Documents\algae.csv")

# %%
concentrations
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
concentrations.groupby("genus").aggregate(["max","min"])
# Out:
#                           species                       group         \
#                               max                  min    max    min
# genus
# Ascophyllum   Ascophyllum_nodosum  Ascophyllum_nodosum  brown  brown
# Cladophora    Cladophora_gracilis  Cladophora_compacta  green  green
# Fucus           Fucus_vesiculosus      Fucus_distichus  brown  brown
# Palmaria         Palmaria_palmata     Palmaria_palmata    red    red
# Saccharina   Saccharina_latissima  Saccharina_japonica  brown  brown
#
#               sucrose              alanin             citrate            \
#                   max       min       max       min       max       min
# genus
# Ascophyllum  6.825467  6.825467  0.875429  0.875429  5.253527  5.253527
# Cladophora   5.712284  2.452623  6.881024  1.648450  6.940588  3.082826
# Fucus        6.786996  3.001472  6.641303  0.346431  6.423606  1.216767
# Palmaria     0.704580  0.704580  3.176440  3.176440  5.573905  5.573905
# ...

# %%
concentrations.groupby("group").describe()
# Out:
#       alanin                                                              \
#        count      mean       std       min       25%       50%       75%
# group
# brown    6.0  3.103846  2.687071  0.346431  0.970384  2.483374  5.272747
# green    3.0  3.997055  2.657050  1.648450  2.555071  3.461692  5.171358
# red      1.0  3.176440       NaN  3.176440  3.176440  3.176440  3.176440
#
#                 citrate              ...    oleic_acid           sucrose  \
#             max   count      mean    ...           75%       max   count
# group                                ...
# brown  6.641303     6.0  4.098597    ...      4.652528  6.405165     6.0
# green  6.881024     3.0  5.288311    ...      2.678951  2.829016     3.0
# red    3.176440     1.0  5.573905    ...      2.245538  2.245538     1.0
#
#
#            mean       std       min       25%      50%       75%       max
# group
# brown  4.709666  2.336471  1.636122  3.070321  5.00397  6.773014  6.825467
# ...

# %%
# %matplotlib inline
concentrations.citrate.hist()

# %%
concentrations.plot.scatter(x='alanin',y='citrate')

# %%
sns.lmplot(x='alanin',y='citrate',hue="group",data=concentrations,fit_reg=False)

# %%
df = pd.read_csv(r"C:\Users\U_M10Q3\Documents\income.csv")

# %%
sns.lineplot(data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-ffa3a02ec526> in <module>()
# ----> 1 sns.lineplot(data=df)
#
# AttributeError: module 'seaborn' has no attribute 'lineplot'

# %%
sns.__version__
# Out:
# '0.7.1'

# %%
# Out:
#   File "<ipython-input-78-1388832da5a8>", line 1
#     pip freeze
#              ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv(r"C:\Users\U_M10Q3\Documents\dataset_209770_6.txt",delimiter=" ")

# %%
sns.lmplot(x="x",y="y",data=df)

# %%
sns.scatterplot(df.iloc[:, 0], df.iloc[:, 1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-f55d89394d49> in <module>()
# ----> 1 sns.scatterplot(df.iloc[:, 0], df.iloc[:, 1])
#
# AttributeError: module 'seaborn' has no attribute 'scatterplot'

# %%
g = pd.read_csv(r"C:\Users\U_M10Q3\Documents\genome_matrix.csv",index_col=0)

# %%
sns.heatmap(data=g,cmap="viridis")

# %%
dh = pd.read_csv(r"C:\Users\U_M10Q3\Documents\dota_hero_stats.csv")

# %%
nor=dh.roles.apply(lambda x: len(x.split(",")))
dh['roles'].str.split(",").str.len().value_counts()
# Out:
# 4    38
# 5    33
# 3    28
# 2     9
# 6     8
# 1     1
# Name: roles, dtype: int64

# %%
iris = pd.read_csv(r"C:\Users\U_M10Q3\Documents\iris.csv")

# %%
for column in iris:
    if column != "Unnamed: 0":
        
        sns.distplot(iris[column],kde_kws={ "label":column})

# %%
sns.pairplot(iris[1:],hue="species")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-05b9271c808c> in <module>()
# ----> 1 sns.pairplot(iris[1:],hue="species")
#
# NameError: name 'sns' is not defined

# %%
df1 = pd.read_csv(r'C:\Users\U_M10Q3\Documents\my_stat_1.csv')

# %%
df1.head()
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            NaN    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9

# %%
df1.fillna(0)
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            0.0    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            0.0    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B      -11
# 9            0.0     9     A      -20

# %%
df1.replace(df1['n_users'],np.mean(df1[df1['n_users']>0]))
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            NaN    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            NaN    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B      -11
# 9            0.0     9     A      -20

# %%
my_stat= df1.fillna(0) 
my_stat_2 = my_stat.query('n_users >= 0')
med = my_stat_2['n_users'].median()
my_stat.loc[my_stat['n_users'] < 0]

# %%
my_stat.loc[my_stat['n_users'] < 0,'n_users']=med

# %%
my_stat
# Out:
#    session_value  time group  n_users
# 0            0.0  12.0     B      9.0
# 1            5.0   5.0     5      5.0
# 2            1.0   8.0     A      1.0
# 3            2.0   9.0     B      3.0
# 4            2.0  10.0     B      9.0
# 5            3.0   8.0     A      8.0
# 6            0.0  11.0     B      5.0
# 7            0.0   9.0     A      4.0
# 8            5.0   5.0     5      5.0
# 9            5.0   5.0     5      5.0

# %%
df1.groupby('group',as_index=False).agg({'session_value': 'mean'}).rename(index=str,columns={'session_value': 'mean_session_value'})
# Out:
#   group  mean_session_value
# 0     A                 1.0
# 1     B                 1.0

# %%
de=pd.read_csv(r"C:\Users\U_M10Q3\Documents\event_data_train.csv")

# %%
de.head(10)
# Out:
#    step_id   timestamp           action  user_id
# 0    32815  1434340848           viewed    17632
# 1    32815  1434340848           passed    17632
# 2    32815  1434340848       discovered    17632
# 3    32811  1434340895       discovered    17632
# 4    32811  1434340895           viewed    17632
# 5    32811  1434340895           passed    17632
# 6    32929  1434340921       discovered    17632
# 7    32929  1434340921           viewed    17632
# 8    32929  1434340939  started_attempt    17632
# 9    32929  1434340944           passed    17632

# %%
de[de.timestamp > 1434340848]
# Out:
#          step_id   timestamp           action  user_id
# 3          32811  1434340895       discovered    17632
# 4          32811  1434340895           viewed    17632
# 5          32811  1434340895           passed    17632
# 6          32929  1434340921       discovered    17632
# 7          32929  1434340921           viewed    17632
# 8          32929  1434340939  started_attempt    17632
# 9          32929  1434340944           passed    17632
# 10         32814  1434340950           viewed    17632
# 11         32814  1434340950       discovered    17632
# 12         32814  1434340950           passed    17632
# 13         32812  1434340991           viewed    17632
# 14         32812  1434340991       discovered    17632
# 15         32812  1434341016  started_attempt    17632
# 16         32812  1434341039           passed    17632
# 17         32816  1434341044           viewed    17632
# 18         32816  1434341044           passed    17632
# ...

# %%
de['date'] = pd.to_datetime(de.timestamp, unit='s')

# %%
de['month']=de.date.dt.month

# %%
de.head(10)
# Out:
#    step_id   timestamp           action  user_id                date  \
# 0    32815  1434340848           viewed    17632 2015-06-15 04:00:48
# 1    32815  1434340848           passed    17632 2015-06-15 04:00:48
# 2    32815  1434340848       discovered    17632 2015-06-15 04:00:48
# 3    32811  1434340895       discovered    17632 2015-06-15 04:01:35
# 4    32811  1434340895           viewed    17632 2015-06-15 04:01:35
# 5    32811  1434340895           passed    17632 2015-06-15 04:01:35
# 6    32929  1434340921       discovered    17632 2015-06-15 04:02:01
# 7    32929  1434340921           viewed    17632 2015-06-15 04:02:01
# 8    32929  1434340939  started_attempt    17632 2015-06-15 04:02:19
# 9    32929  1434340944           passed    17632 2015-06-15 04:02:24
#
#           day  month
# 0  2015-06-15      6
# 1  2015-06-15      6
# 2  2015-06-15      6
# 3  2015-06-15      6
# 4  2015-06-15      6
# 5  2015-06-15      6
# 6  2015-06-15      6
# 7  2015-06-15      6
# ...

# %%
de[de.action == 'passed'].groupby('user_id').step_id.count().head()
# Out:
# user_id
# 2     9
# 3    87
# 5    11
# 7     1
# 8    84
# Name: step_id, dtype: int64

# %%
import datetime
de[(de.action == 'passed') & (de.day > datetime.date(2016,6,15))].groupby('user_id').agg({'step_id': 'count'}).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x01691050>]], dtype=object)

# %%
ds=pd.read_csv(r"C:\Users\U_M10Q3\Documents\submissions_data_train.csv")

# %%
ds['date']=pd.to_datetime(ds.timestamp,unit='s').dt.date
ds.head()
# Out:
#    step_id   timestamp submission_status  user_id        date
# 0    31971  1434349275           correct    15853  2015-06-15
# 1    31972  1434348300           correct    15853  2015-06-15
# 2    31972  1478852149             wrong    15853  2016-11-11
# 3    31972  1478852164           correct    15853  2016-11-11
# 4    31976  1434348123             wrong    15853  2015-06-15

# %%
ds.pivot_table(index='user_id',columns='submission_status',values='step_id', aggfunc='count',fill_value=0).head()
# Out:
# submission_status  correct  wrong
# user_id
# 2                        2      0
# 3                       29     23
# 5                        2      2
# 8                        9     21
# 14                       0      1

# %%
ds['count']=ds[ds.submission_status == 'correct'].groupby('user_id').agg({'submission_status': 'count'})

# %%
ds.drop('count',axis=1,inplace=True)
ds.head()
# Out:
#    step_id   timestamp submission_status  user_id        date
# 0    31971  1434349275           correct    15853  2015-06-15
# 1    31972  1434348300           correct    15853  2015-06-15
# 2    31972  1478852149             wrong    15853  2016-11-11
# 3    31972  1478852164           correct    15853  2016-11-11
# 4    31976  1434348123             wrong    15853  2015-06-15

# %%
ds.pivot_table(index='user_id',columns='submission_status',values='step_id',aggfunc='count') \
.sort_values('correct',ascending=False).head()
# Out:
# submission_status  correct  wrong
# user_id
# 1046                 421.0  513.0
# 5552                 186.0   93.0
# 17135                168.0  177.0
# 6183                 142.0   65.0
# 8461                 135.0   42.0
