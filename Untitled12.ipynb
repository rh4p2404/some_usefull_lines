# %%
s="s_sourcedata"
t="t_sourcedata"
tables=[
"DMHDB.AGG_FRAT_EXPERIMENT_HDIM"
,"DMHDB.AGTBALLIND_VHIST"
,"DMHDB.AGTSIMPLEIND_STAT"
,"DMHDB.ASS_SUBJECT_SHIST"
,"DMHDB.AT_AGG_NAME_HDIM"
,"DMHDB.AT_ANK_FACTOR_SHIST"
,"DMHDB.AT_BAL_RATE_SHIST"
,"DMHDB.AT_BRANCH_MEASURE_1_SHIST"
,"DMHDB.AT_BRANCH_MEASURE_V_STAT"
,"DMHDB.AT_BRANCH_RISK_VHIST"
,"DMHDB.AT_CORRECT_RATING_SHIST"
,"DMHDB.AT_COUNTRY_RATING_PERC_SHIST"
,"DMHDB.AT_DISCOUNTRATE_VHIST"
,"DMHDB.AT_DISCOUNT_1_VHIST"
,"DMHDB.AT_DISCOUNT_V_STAT"
,"DMHDB.AT_FACTOR_SHIST"
,"DMHDB.AT_FORM_CODE_HDIM"
,"DMHDB.AT_INDUSTRY_RISK_SHIST"
,"DMHDB.AT_LIST_VALUE_HDIM"
,"DMHDB.AT_MOTHER_PART_SHIST"
,"DMHDB.AT_PROCRATE_VHIST"
,"DMHDB.AT_SIGNAL_SHIST"
,"DMHDB.AT_SUPPORT_RATING_SHIST"
,"DMHDB.DET_ANK_FACTOR_SDIM"
,"DMHDB.DET_BANKCOEF_HDIM"
,"DMHDB.DET_BANK_HDIM"
,"DMHDB.DET_BRANCH_EDIM"
,"DMHDB.DET_COUNTRY_EDIM"
,"DMHDB.DET_COUNTRY_RATING_SHIST"
,"DMHDB.DET_CURRENCY_HDIM"
,"DMHDB.DET_FACTOR_SHIST"
,"DMHDB.DET_FINSTR_HDIM"
,"DMHDB.DET_GUARANTY_TYPE_SHIST"
,"DMHDB.DET_JURIDIC_PERSON_HDIM"
,"DMHDB.DET_MODEL_SHIST"
,"DMHDB.DET_OKATO_HDIM"
,"DMHDB.DET_OKVED_EDIM"
,"DMHDB.DET_PRODUCT_HDIM"
,"DMHDB.DET_SCALE_SHIST"
,"DMHDB.DET_SIGNAL_SDIM"
,"DMHDB.DET_SUBJECT_HDIM"
,"DMHDB.DET_SUPPORT_VALUE_SHIST"
,"DMHDB.DET_TYPEINFO_HDIM"
,"DMHDB.DET_TYPE_RATE_HDIM"
,"DMHDB.FCT_ASSETS_V_STAT"
,"DMHDB.FCT_BANKCOEFVALUE_1_VHIST"
,"DMHDB.FCT_BANKCOEFVALUE_V_STAT"
,"DMHDB.FCT_CF_V_STAT"
,"DMHDB.FCT_CLIENTS_V_STAT"
,"DMHDB.FCT_CONSTRUCTIONS_V_STAT"
,"DMHDB.FCT_CONTRACT_V_STAT"
,"DMHDB.FCT_CREDITPORT_V_STAT"
,"DMHDB.FCT_DATACOMMENT_STAT"
,"DMHDB.FCT_DETAILS_TRAN"
,"DMHDB.FCT_FINSTR_RATE_1_SHIST"
,"DMHDB.FCT_FINSTR_RATE_V_STAT"
,"DMHDB.FCT_FIN_DATA_1_SHIST"
,"DMHDB.FCT_FIN_DATA_V_STAT"
,"DMHDB.FCT_INVESTMENT_V_STAT"
,"DMHDB.FCT_LEASING_FINDATA_V_STAT"
,"DMHDB.FCT_LIABILITIES_V_STAT"
,"DMHDB.FCT_MARKETSHARE_V_STAT"
,"DMHDB.FCT_OFFBAL_LIABILITIES_V_STAT"
,"DMHDB.FCT_PLEDGE_1_SHIST"
,"DMHDB.FCT_PLEDGE_V_STAT"
,"DMHDB.FCT_SEGMENTATION_1_SHIST"
,"DMHDB.FCT_SEGMENTATION_V_STAT"
,"DMHDB.FCT_SHAREHOLDERS_V_STAT"
,"DMHDB.FCT_SIGNAL_DATA_V_STAT"
,"DMHDB.FCT_TURNOVER_V_STAT"
,"DMHDB.FCT_UNFIN_DATA_1_SHIST"
,"DMHDB.FCT_UNFIN_DATA_V_STAT"
,"DMHDB.QUE_TASKACTIVATION_TRAN"
,"DMHDB.SRP_OBJECT_HDIM"
,"DMHDB.WIF_EXPERIMENT_TRAN"]

# %%
for a in tables:
    print(f"""truncate table {a};\ncommit;\ninsert into {a}  select * from {a}@HDBPRD;\ncommit;\n""")
# Out:
# truncate table DMHDB.AGG_FRAT_EXPERIMENT_HDIM;
# commit;
# insert into DMHDB.AGG_FRAT_EXPERIMENT_HDIM  select * from DMHDB.AGG_FRAT_EXPERIMENT_HDIM@HDBPRD;
# commit;
#
# truncate table DMHDB.AGTBALLIND_VHIST;
# commit;
# insert into DMHDB.AGTBALLIND_VHIST  select * from DMHDB.AGTBALLIND_VHIST@HDBPRD;
# commit;
#
# truncate table DMHDB.AGTSIMPLEIND_STAT;
# commit;
# insert into DMHDB.AGTSIMPLEIND_STAT  select * from DMHDB.AGTSIMPLEIND_STAT@HDBPRD;
# commit;
#
# truncate table DMHDB.ASS_SUBJECT_SHIST;
# commit;
# insert into DMHDB.ASS_SUBJECT_SHIST  select * from DMHDB.ASS_SUBJECT_SHIST@HDBPRD;
# commit;
#
# truncate table DMHDB.AT_AGG_NAME_HDIM;
# commit;
# insert into DMHDB.AT_AGG_NAME_HDIM  select * from DMHDB.AT_AGG_NAME_HDIM@HDBPRD;
# commit;
#
# truncate table DMHDB.AT_ANK_FACTOR_SHIST;
# commit;
# insert into DMHDB.AT_ANK_FACTOR_SHIST  select * from DMHDB.AT_ANK_FACTOR_SHIST@HDBPRD;
# commit;
#
# truncate table DMHDB.AT_BAL_RATE_SHIST;
# commit;
# ...

# %%
import cx_Oracle
import mysql.connector
import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d6d4205a30ef> in <module>()
# ----> 1 import cx_Oracle
#       2 import mysql.connector
#       3 import datetime
#
# ModuleNotFoundError: No module named 'cx_Oracle'

# %%
0 - "2"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-40eeb028f2e7> in <module>()
# ----> 1 0 - "2"
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
"0" + "2"
# Out:
# '02'
